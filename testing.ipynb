# %%
import json
import pandas as pd
from numpy import trapz
from statistics import mean
from sklearn.preprocessing import QuantileTransformer

# %%
with open("data/parfumo/collection/graph.json", "r") as f:
    graph = json.load(f)

nodes_df = pd.DataFrame(graph["nodes"])

# %%
components = ["type_spicy", "type_woody", "type_sweet", "occasion_evening"]
# components = ["type_gourmand", "type_woody"]

# %%
nodes_df = nodes_df[
    nodes_df["collection_group"].isin(["I have", "Decants", "Miniatures"])
]
nodes_df = nodes_df[["short_name"] + components]

nodes_df["trapz"] = nodes_df[components].apply(trapz, axis=1)
nodes_df["mean"] = nodes_df[components].apply(mean, axis=1)

# %%
nodes_df[components + ["trapz", "mean"]] = pd.DataFrame(
    QuantileTransformer().fit_transform(nodes_df[components + ["trapz", "mean"]].values)
)
# Out:
# c:\Users\baker\fragscrape\venv\Lib\site-packages\sklearn\preprocessing\_data.py:2762: UserWarning: n_quantiles (1000) is greater than the total number of samples (69). n_quantiles is set to n_samples.
#   warnings.warn(

# %%
nodes_df[nodes_df[components].apply(min, axis=1) > 0].sort_values(
    "trapz", ascending=False
)
# Out:
#                                            short_name  type_spicy  type_woody  \
# 50                    The One for Men Dolce & Gabbana    0.985294    0.897059
# 21              La Nuit de L'Homme Yves Saint Laurent    1.000000    0.691176
# 55  Emporio Armani - Stronger With You Absolutely ...    0.691176    0.558824
# 57                           Oud for Greatness Initio    0.897059    0.985294
# 34                               Angels' Share Kilian    0.735294    0.544118
# 33                           Haltane Parfums de Marly    0.911765    0.941176
# 54         Gentleman Givenchy Réserve Privée Givenchy    0.764706    0.735294
# 10                         Select Night Mercedes-Benz    0.794118    0.661765
# 37                   Apple Brandy on the Rocks Kilian    0.647059    0.794118
# 46                         Armani Code Giorgio Armani    0.779412    0.720588
# 43                            Layton Parfums de Marly    0.750000    0.529412
# 16                              Play Intense Givenchy    0.602941    0.433824
# 64                             Herod Parfums de Marly    0.838235    0.397059
# 30                             1 Million Paco Rabanne    0.661765    0.235294
# 52                        Santal Eau de Santal Floris    0.926471    1.000000
# 48                           Althaïr Parfums de Marly    0.500000    0.308824
# 45                            Dior Homme Intense Dior    0.308824    0.647059
# 9                            Uomo Salvatore Ferragamo    0.588235    0.294118
# 49                           Club Black Mercedes-Benz    0.323529    0.338235
# 41   Musc Ravageur Editions de Parfums Frédéric Malle    0.823529    0.323529
# 35                                 Signature Zaharoff    0.852941    0.955882
# 1        Armani Code Absolu pour Homme Giorgio Armani    0.573529    0.176471
# 29             Ishq Al Shuyukh Silver Lattafa / لطافة    0.514706    0.867647
# 23                             Ombré Leather Tom Ford    0.808824    0.500000
# 31                         Le Mâle Jean Paul Gaultier    0.558824    0.220588
# 53                                    Royal Oud Creed    0.705882    0.926471
# 0                           Gucci pour Homme II Gucci    0.882353    0.838235
# 8                          L'Homme Yves Saint Laurent    0.720588    0.676471
